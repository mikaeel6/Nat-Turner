# %% [markdown]
# <a href="https://colab.research.google.com/github/mikaeel6/Nat-Turner/blob/master/craftMir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tiktoken
import os
# !pip install tiktoken
import os
import urllib.request
from google.colab import files
uploaded = files.upload("the-verdict.txt")
# uploaded is a dictionary containing the uploaded files
# Access the file content using its name as the key
filename = list(uploaded.keys())[0]  # Get the first filename from the dictionary
with open(filename, "r") as file:
    text = file.read()
print(text)
len(text)

# %%
len(text)

# %%
import tiktoken

# %%
tiktoken.__version__
# Out:
# '0.9.0'

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
tokenizer.encode(text)
# Out:
# [40,
#  367,
#  2885,
#  1464,
#  1807,
#  3619,
#  402,
#  271,
#  10899,
#  2138,
#  257,
#  7026,
#  2429,
#  72,
#  436,
#  71,
#  619,
#  257,
#  922,
#  5891,
#  1576,
#  568,
#  340,
#  373,
#  645,
#  1049,
#  5975,
#  284,
#  502,
#  284,
#  3285,
#  326,
#  287,
#  262,
#  6001,
#  286,
#  465,
#  13476,
#  339,
#  550,
#  5710,
#  465,
#  12036,
#  6405,
#  257,
#  5527,
#  27075,
#  290,
#  4920,
#  2241,
#  287,
#  257,
#  4489,
#  64,
#  319,
#  262,
#  34686,
#  41976,
#  7486,
#  314,
#  2138,
#  1807,
#  340,
#  561,
#  423,
#  587,
#  10598,
#  393,
#  28537,
#  198,
#  198,
#  464,
#  6001,
#  286,
#  465,
#  13476,
#  5562,
#  373,
#  644,
#  262,
#  1466,
#  1444,
#  340,
#  314,
#  460,
#  3285,
#  9074,
#  46606,
#  536,
#  5469,
#  14363,
#  938,
#  4842,
#  1650,
#  353,
#  2934,
#  489,
#  3255,
#  465,
#  48422,
#  540,
#  450,
#  67,
#  3299,
#  3226,
#  1781,
#  663,
#  1016,
#  284,
#  3758,
#  262,
#  1988,
#  286,
#  616,
#  4286,
#  835,
#  510,
# ...
